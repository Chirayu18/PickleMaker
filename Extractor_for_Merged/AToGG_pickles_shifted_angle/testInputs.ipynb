# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
combined_EBM = np.load("pickles_combined/trueAngleScaled_target.pickle",allow_pickle=True)
plt.hist(combined_EBM,bins=100)
EBM = {}
combined_EBM2 = []
for i in range(100,1001,100):
    EBM[i] = np.load("pickles_AToGG_M"+str(i)+"/trueEBMScaled_target.pickle",allow_pickle=True)
    combined_EBM2.extend(list(EBM[i]))
len(combined_EBM2)
# Out:
# 35371

# %%
plt.hist(EBM[800],bins=100)
plt.hist(EBM[300],bins=100)
# Out:
# (array([  2.,   1.,   3.,   4.,   0.,   1.,   1.,   1.,   0.,   1.,   0.,
#           0.,   0.,   1.,   0.,   0.,   0.,   6.,  21.,  38.,  51.,  63.,
#          79.,  78.,  65.,  74.,  80.,  85.,  89.,  87., 108.,  82., 122.,
#         104., 130., 127., 124., 124., 114., 104.,  89.,  95.,  90.,  93.,
#          88.,  72.,  78.,  75.,  68.,  69.,  40.,  62.,  46.,  52.,  41.,
#          51.,  64.,  47.,  47.,  43.,  37.,  45.,  47.,  33.,  26.,  27.,
#          26.,  25.,  22.,  19.,  16.,  28.,  18.,  16.,  25.,  22.,  10.,
#          14.,  21.,  12.,  11.,  18.,  11.,   6.,  13.,  12.,  12.,  11.,
#          13.,   5.,   6.,  10.,   4.,   6.,  11.,   7.,   2.,   3.,   3.,
#           4.]),
#  array([ -2.25122795,  -0.74231638,   0.7665952 ,   2.27550677,
#           3.78441835,   5.29332992,   6.8022415 ,   8.31115307,
#           9.82006465,  11.32897622,  12.8378878 ,  14.34679937,
#          15.85571095,  17.36462252,  18.8735341 ,  20.38244567,
# ...

# %%
for i in range(100,1001,100):
    if(i==500):
        continue
    peak = np.mean(EBM[i])
    EBM[i] = [j +peak*15 for j in EBM[i]] 
    print(peak)
# Out:
# 21.259183308005714
# 42.3286275584114
# 63.68398010566267
# 84.63105317877114
# 126.58825121570521
# 148.72864496387098
# 169.55964435574236
# 190.17224753670422
# 211.17109963552815

# %%
combined_EBM3 = []
for i in range(100,1001,100):
    if(i==500):
        continue
    combined_EBM3.extend(np.array(EBM[i]))
plt.hist(np.array(combined_EBM3)/10000,bins=100)
# Out:
# (array([3.470e+03, 4.810e+02, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 7.400e+01, 2.886e+03, 8.930e+02,
#         7.700e+01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         3.000e+00, 3.870e+02, 2.169e+03, 1.011e+03, 3.190e+02, 4.800e+01,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.500e+01, 8.080e+02,
#         1.711e+03, 8.890e+02, 3.520e+02, 1.520e+02, 1.100e+01, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.000e+00, 1.300e+01,
#         3.060e+02, 1.045e+03, 1.137e+03, 6.430e+02, 4.100e+02, 2.020e+02,
#         1.240e+02, 4.900e+01, 9.000e+00, 8.000e+00, 1.510e+02, 8.110e+02,
#         1.049e+03, 7.470e+02, 4.660e+02, 3.360e+02, 1.750e+02, 1.170e+02,
#         7.200e+01, 1.000e+01, 3.930e+02, 7.870e+02, 9.380e+02, 6.280e+02,
#         4.360e+02, 3.030e+02, 1.830e+02, 1.250e+02, 8.500e+01, 1.590e+02,
# ...

# %%
for i in range(100,1001,100):
    if(i==500):
        continue
    peak = np.mean(EBM[i])
    EBM[i] = [j - peak*10/11 for j in EBM[i]] 
    print(peak)
# Out:
# 340.14693292809136
# 677.2580409345824
# 1018.9436816906027
# 1354.0968508603382
# 2025.4120194512836
# 2379.6583194219356
# 2712.954309691878
# 3042.7559605872675
# 3378.7375941684504

# %%
combined_EBM4 = []
for i in range(100,1001,100):
    if(i==500):
        continue
    peak = np.mean(EBM[i])
    combined_EBM4.extend(np.array(EBM[i]))
plt.hist(combined_EBM4,bins=100)
# Out:
# (array([8.000e+00, 1.760e+02, 1.066e+03, 1.228e+03, 8.210e+02, 8.390e+02,
#         7.340e+02, 9.210e+02, 8.350e+02, 7.360e+02, 7.120e+02, 8.740e+02,
#         9.300e+02, 7.530e+02, 7.090e+02, 6.500e+02, 6.660e+02, 6.440e+02,
#         6.020e+02, 5.240e+02, 5.330e+02, 5.580e+02, 5.290e+02, 5.740e+02,
#         6.560e+02, 6.950e+02, 6.410e+02, 6.660e+02, 6.880e+02, 7.030e+02,
#         6.420e+02, 7.350e+02, 7.000e+02, 6.830e+02, 6.300e+02, 6.920e+02,
#         6.580e+02, 6.060e+02, 5.960e+02, 5.650e+02, 5.340e+02, 5.030e+02,
#         5.060e+02, 4.960e+02, 4.690e+02, 4.450e+02, 3.970e+02, 3.350e+02,
#         3.470e+02, 3.120e+02, 2.970e+02, 2.860e+02, 2.630e+02, 2.260e+02,
#         2.240e+02, 2.010e+02, 1.960e+02, 1.640e+02, 1.560e+02, 1.620e+02,
#         1.360e+02, 1.280e+02, 1.200e+02, 1.200e+02, 9.600e+01, 9.800e+01,
#         8.700e+01, 8.700e+01, 6.900e+01, 7.800e+01, 6.100e+01, 5.500e+01,
#         4.600e+01, 6.200e+01, 4.100e+01, 4.200e+01, 3.600e+01, 3.800e+01,
# ...
